# %%
import requests
r=requests.get("https://www.kma.go.kr/repositary/xml/fct/mon/img/fct_mon1rss_108_20250904.xml")
print(r.status_code)
print(r.text)
# Out:
# 200
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# 	<channel>
# 		<title>기상청 육상 장기예보 1개월 전망</title>
# 		<link>http://www.weather.go.kr/w/climate/montr-prediction/month1.do</link>
# 		<description>기상청 날씨 웹서비스</description>
# 		<language>ko</language>
# 		<generator>기상청</generator>
# 		<pubDate>2025년 09월 01일 (목)요일 12:40:00</pubDate>
# 		<item>
# 			<author>기상청</author>
# 			<category>육상 장기예보 1개월 전망</category>
# 			<title>1개월전망 전국 - 2025년 9월 4일 11시  발표</title>
# 			<link>
# 				http://www.weather.go.kr/w/climate/montr-prediction/month1.do
# 			</link>
# 			<guid>
# 				http://www.weather.go.kr/w/climate/montr-prediction/month1.do
# 			</guid>
# 			<description>
# 				<header>
# 					<title>1개월전망</title>
#                 			<date>2025년 9월 15일 ~ 10월 12일</date>
#                 			<ydate>2025년 9월 4일 11시</ydate>
#                 			<next_ydate>2025년 9월 11일 11시</next_ydate>
# 				</header>
# 				<body>
# 					<summary>
#                      				<![CDATA[  ]]>
# ...

# %%
r=requests.get("https://www.weather.go.kr/w/rss/dfs/hr1-forecast.do?zone=1141-58500")
print(r.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <rss version="2.0">
# <channel>
# <title>기상청 1시간단위 동네예보 웹서비스 - 서울특별시 동작구 신대방제2동</title>
# <link>https://www.weather.go.kr/w/index.do</link>
# <description>동네예보 웹서비스</description>
# <language>ko</language>
# <generator>동네예보</generator>
# <pubDate>2025년 09월 08일 (월)요일 11:00</pubDate>
# 	<item>
# 	<author>기상청</author>
# 	<category>서울특별시 동작구 신대방제2동</category>
# 	<title>1시간단위 동네예보(도표) : 서울특별시 동작구 신대방제2동 [X=59,Y=125]</title>
# 	<link>https://www.weather.go.kr/w/weather/forecast/short-term.do#dong/1159068000</link>
# 	<guid>https://www.weather.go.kr/w/weather/forecast/short-term.do#dong/1159068000</guid>
# 	<description>
# 		<header>
# 			<tm>202509081100</tm>
# 			<ts>3</ts>
# 			<x>59</x>
# 			<y>125</y>
# 		</header>
# 		<body>
# 			<data seq="0">
# <hour>13</hour>
# <day>0</day>
# <temp>29.0</temp>
# <tmx>30.0</tmx>
# <tmn>-999.0</tmn>
# <sky>3</sky>
# <pty>0</pty>
# <wfKor>구름 많음</wfKor>
# <wfEn>Mostly Cloudy</wfEn>
# <pcp>0.0</pcp>
# ...
